# %%
import warnings
warnings.filterwarnings('ignore')

# %%
S1 = 'The truth is out there.'

# %%
print(S1)
# Out:
# The truth is out there.

# %%
print('=' * 40)
print('\t', S1)
print('=' * 40)
# Out:
# ========================================
# 	 The truth is out there.
# ========================================

# %%
S2 = 'The truth is'
S3 = ' out there.'

# %%
S2 + S3
# Out:
# 'The truth is out there.'

# %%
S2 * 3
# Out:
# 'The truth isThe truth isThe truth is'

# %%
S3 * 3
# Out:
# ' out there. out there. out there.'

# %%
S1[1]
# Out:
# 'h'

# %%
S1[5]
# Out:
# 'r'

# %%
S1[0]
# Out:
# 'T'

# %%
S1[-1]
# Out:
# '.'

# %%
S1[-13]
# Out:
# 'i'

# %%
S1[-18]
# Out:
# 'r'

# %%
print(S1)
# Out:
# The truth is out there.

# %%
S1[4] + S1[5] + S1[6] + S1[7] + S1[8]
# Out:
# 'truth'

# %%
S1[4:9]
# Out:
# 'truth'

# %%
S1[10:12]
# Out:
# 'is'

# %%
S1[:12]
# Out:
# 'The truth is'

# %%
S1[13:]
# Out:
# 'out there.'

# %%
S1[13:-7]
# Out:
# 'out'

# %%
L1 = [1, 3, 5, 7, 9]

# %%
print(L1)
# Out:
# [1, 3, 5, 7, 9]

# %%
print(type(L1))
print(type(L1[0]))
# Out:
# <class 'list'>
# <class 'int'>

# %%
L2 = ['HP', 'IBM', 'DELL', 'EMC', 'MS']

# %%
print(L2)
# Out:
# ['HP', 'IBM', 'DELL', 'EMC', 'MS']

# %%
print(type(L2))
print(type(L2[0]))
# Out:
# <class 'list'>
# <class 'str'>

# %%
L3  = [1, '삼', 5, '칠', 9]

# %%
print(type(L3))
print(type(L3[0]))
print(type(L3[1]))
# Out:
# <class 'list'>
# <class 'int'>
# <class 'str'>

# %%
L4  = [1, 3, ['HP', 'MS']]

# %%
print(L4)
# Out:
# [1, 3, ['HP', 'MS']]

# %%
print(type(L4))
print(type(L4[1]))
print(type(L4[2]))
print(type(L4[2][0]))
# Out:
# <class 'list'>
# <class 'int'>
# <class 'list'>
# <class 'str'>

# %%
L5 = [5, 7, ('IBM', 'EMC')]

# %%
print(type(L5))
print(type(L5[1]))
print(type(L5[2]))
print(type(L5[2][0]))
# Out:
# <class 'list'>
# <class 'int'>
# <class 'tuple'>
# <class 'str'>

# %%
print(L1)
# Out:
# [1, 3, 5, 7, 9]

# %%
L1[2]
# Out:
# 5

# %%
L1[2] + L1[4]
# Out:
# 14

# %%
L1[-2]
# Out:
# 7

# %%
print(L4)
# Out:
# [1, 3, ['HP', 'MS']]

# %%
L4[1]
# Out:
# 3

# %%
L4[2]
# Out:
# ['HP', 'MS']

# %%
L4[2][1]
# Out:
# 'MS'

# %%
L4[2][0] + L4[2][1]
# Out:
# 'HPMS'

# %%
print(L1)
# Out:
# [1, 3, 5, 7, 9]

# %%
L1[1:4]
# Out:
# [3, 5, 7]

# %%
L1[:3]
# Out:
# [1, 3, 5]

# %%
L1[2:]
# Out:
# [5, 7, 9]

# %%
L6 = [1, 3, 5, [2, 4, 6]]

# %%
print(L6)
# Out:
# [1, 3, 5, [2, 4, 6]]

# %%
L6[2:]
# Out:
# [5, [2, 4, 6]]

# %%
L6[3]
# Out:
# [2, 4, 6]

# %%
L6[3][0:2]
# Out:
# [2, 4]

# %%
print(L1)
# Out:
# [1, 3, 5, 7, 9]

# %%
L1[2] = 6

# %%
print(L1)
# Out:
# [1, 3, 6, 7, 9]

# %%
print(L1)
# Out:
# [1, 3, 6, 7, 9]

# %%
L1[2:4] = []

# %%
print(L1)
# Out:
# [1, 3, 9]

# %%
del L1[2]

# %%
print(L1)
# Out:
# [1, 3]

# %%
del L1

# %%
print(L1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-106-dd7a48c09dc8> in <module>()
# ----> 1 print(L1)
#
# NameError: name 'L1' is not defined

# %%
L7 = [8, 3, 9, 2, 1]

# %%
print(L7)
# Out:
# [8, 3, 9, 2, 1]

# %%
L7.sort()

# %%
print(L7)
# Out:
# [1, 2, 3, 8, 9]

# %%
L7.reverse()

# %%
print(L7)
# Out:
# [9, 8, 3, 2, 1]

# %%
L7.append(0)

# %%
L7.insert(2,5)

# %%
print(L7)
# Out:
# [9, 8, 5, 3, 2, 1, 0]

# %%
L8 = [1, 3, 5, 7, 9]
L9 = [2, 4, 6, 8, 10]

# %%
L8 + L9
# Out:
# [1, 3, 5, 7, 9, 2, 4, 6, 8, 10]

# %%
L8 * 2
# Out:
# [1, 3, 5, 7, 9, 1, 3, 5, 7, 9]

# %%
L9 * 3
# Out:
# [2, 4, 6, 8, 10, 2, 4, 6, 8, 10, 2, 4, 6, 8, 10]
