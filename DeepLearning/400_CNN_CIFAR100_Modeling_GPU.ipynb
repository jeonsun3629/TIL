# %% [markdown]
# # CIFAR100 - Categorical Classification
# > # Convolutional Neural Network
# ## Import Keras

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# * import Keras

# %%
import keras

keras.__version__
# Out:
# '2.4.3'

# %% [markdown]
# # I. CIFAR100 Data_Set Load

# %%
from keras.datasets import cifar100

(X_train, y_train), (X_test, y_test) = cifar100.load_data(label_mode = 'fine')
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169009152/169001437 [==============================] - 2s 0us/step

# %% [markdown]
# # II. Data Preprocessing

# %% [markdown]
# > ## 1) Reshape and Normalization

# %% [markdown]
# * reshape

# %%
X_train = X_train.reshape((50000,  32, 32, 3))
X_test = X_test.reshape((10000,  32, 32, 3))

# %% [markdown]
# * Normalization

# %%
X_train = X_train.astype(float) / 255
X_test = X_test.astype(float) / 255

# %% [markdown]
# > ## 2) One Hot Encoding

# %%
from keras.utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# # III. MNIST Keras Modeling

# %% [markdown]
# > ## 1) Model Define

# %%
from tensorflow.keras import models
from tensorflow.keras import layers

model = models.Sequential()
model.add(layers.Conv2D(filters=128, kernel_size=(3,3), activation='relu', input_shape=(32, 32, 3)))
model.add(layers.MaxPool2D(pool_size=(2,2)))
model.add(layers.Conv2D(filters=128, kernel_size=(3,3), activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))
model.add(layers.Conv2D(filters=128, kernel_size=(3,3), activation='relu'))

model.add(layers.Flatten())
model.add(layers.Dense(units=256, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(units=100, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 128)       3584
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 128)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 128)       147584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 128)         147584
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               524544
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               25700
# =================================================================
# Total params: 848,996
# Trainable params: 848,996
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# > ## 2) Model Compile

# %% [markdown]
# * 모델 학습방법 설정

# %%
model.compile(loss = 'categorical_crossentropy',
              optimizer = 'adam',
              metrics = ['accuracy'])

# %% [markdown]
# > ## 3) Model Fit

# %% [markdown]
# * 약 5분

# %%
# %%time

Hist_mnist = model.fit(X_train, y_train,
                       epochs = 50,
                       batch_size = 128,
                       validation_split = 0.2)
# Out:
# Epoch 1/50
# 313/313 [==============================] - 38s 16ms/step - loss: 4.4773 - accuracy: 0.0229 - val_loss: 3.9566 - val_accuracy: 0.0955
# Epoch 2/50
# 313/313 [==============================] - 4s 14ms/step - loss: 3.9207 - accuracy: 0.0957 - val_loss: 3.5483 - val_accuracy: 0.1638
# Epoch 3/50
# 313/313 [==============================] - 4s 14ms/step - loss: 3.5650 - accuracy: 0.1511 - val_loss: 3.3061 - val_accuracy: 0.2059
# Epoch 4/50
# 313/313 [==============================] - 4s 14ms/step - loss: 3.3499 - accuracy: 0.1913 - val_loss: 3.0949 - val_accuracy: 0.2422
# Epoch 5/50
# 313/313 [==============================] - 4s 14ms/step - loss: 3.1958 - accuracy: 0.2223 - val_loss: 2.9666 - val_accuracy: 0.2691
# Epoch 6/50
# 313/313 [==============================] - 4s 14ms/step - loss: 3.0482 - accuracy: 0.2501 - val_loss: 2.8490 - val_accuracy: 0.2954
# Epoch 7/50
# 313/313 [==============================] - 4s 14ms/step - loss: 2.9184 - accuracy: 0.2685 - val_loss: 2.8044 - val_accuracy: 0.3102
# Epoch 8/50
# 313/313 [==============================] - 4s 14ms/step - loss: 2.8289 - accuracy: 0.2874 - val_loss: 2.6779 - val_accuracy: 0.3279
# Epoch 9/50
# 313/313 [==============================] - 4s 14ms/step - loss: 2.7046 - accuracy: 0.3134 - val_loss: 2.6348 - val_accuracy: 0.3351
# Epoch 10/50
# 313/313 [==============================] - 4s 14ms/step - loss: 2.6400 - accuracy: 0.3215 - val_loss: 2.5816 - val_accuracy: 0.3488
# Epoch 11/50
# 313/313 [==============================] - 4s 14ms/step - loss: 2.5623 - accuracy: 0.3418 - val_loss: 2.5682 - val_accuracy: 0.3474
# Epoch 12/50
# 313/313 [==============================] - 4s 14ms/step - loss: 2.4923 - accuracy: 0.3543 - val_loss: 2.5310 - val_accuracy: 0.3571
# Epoch 13/50
# 313/313 [==============================] - 4s 14ms/step - loss: 2.4259 - accuracy: 0.3624 - val_loss: 2.4974 - val_accuracy: 0.3667
# Epoch 14/50
# 313/313 [==============================] - 4s 14ms/step - loss: 2.3788 - accuracy: 0.3777 - val_loss: 2.4764 - val_accuracy: 0.3708
# Epoch 15/50
# 313/313 [==============================] - 4s 14ms/step - loss: 2.3280 - accuracy: 0.3837 - val_loss: 2.5031 - val_accuracy: 0.3661
# Epoch 16/50
# 313/313 [==============================] - 4s 14ms/step - loss: 2.2658 - accuracy: 0.3986 - val_loss: 2.4772 - val_accuracy: 0.3699
# Epoch 17/50
# 313/313 [==============================] - 4s 14ms/step - loss: 2.2235 - accuracy: 0.4090 - val_loss: 2.4653 - val_accuracy: 0.3714
# Epoch 18/50
# 313/313 [==============================] - 4s 14ms/step - loss: 2.1705 - accuracy: 0.4213 - val_loss: 2.4456 - val_accuracy: 0.3827
# Epoch 19/50
# 313/313 [==============================] - 4s 14ms/step - loss: 2.1055 - accuracy: 0.4289 - val_loss: 2.4185 - val_accuracy: 0.3851
# Epoch 20/50
# 313/313 [==============================] - 4s 14ms/step - loss: 2.0814 - accuracy: 0.4352 - val_loss: 2.4651 - val_accuracy: 0.3813
# Epoch 21/50
# 313/313 [==============================] - 4s 14ms/step - loss: 2.0301 - accuracy: 0.4476 - val_loss: 2.4307 - val_accuracy: 0.3831
# Epoch 22/50
# 313/313 [==============================] - 4s 14ms/step - loss: 2.0011 - accuracy: 0.4534 - val_loss: 2.4311 - val_accuracy: 0.3870
# Epoch 23/50
# 313/313 [==============================] - 4s 14ms/step - loss: 1.9383 - accuracy: 0.4701 - val_loss: 2.4517 - val_accuracy: 0.3825
# Epoch 24/50
# 313/313 [==============================] - 4s 14ms/step - loss: 1.9122 - accuracy: 0.4691 - val_loss: 2.4640 - val_accuracy: 0.3840
# Epoch 25/50
# 313/313 [==============================] - 4s 14ms/step - loss: 1.8672 - accuracy: 0.4804 - val_loss: 2.4686 - val_accuracy: 0.3884
# Epoch 26/50
# 313/313 [==============================] - 4s 14ms/step - loss: 1.8218 - accuracy: 0.4879 - val_loss: 2.4803 - val_accuracy: 0.3865
# Epoch 27/50
# 313/313 [==============================] - 4s 14ms/step - loss: 1.7964 - accuracy: 0.4936 - val_loss: 2.4975 - val_accuracy: 0.3845
# Epoch 28/50
# 313/313 [==============================] - 4s 14ms/step - loss: 1.7735 - accuracy: 0.5009 - val_loss: 2.5175 - val_accuracy: 0.3846
# Epoch 29/50
# 313/313 [==============================] - 4s 14ms/step - loss: 1.7399 - accuracy: 0.5099 - val_loss: 2.5297 - val_accuracy: 0.3843
# Epoch 30/50
# 313/313 [==============================] - 4s 14ms/step - loss: 1.6975 - accuracy: 0.5138 - val_loss: 2.5125 - val_accuracy: 0.3874
# Epoch 31/50
# 313/313 [==============================] - 4s 14ms/step - loss: 1.6688 - accuracy: 0.5241 - val_loss: 2.5737 - val_accuracy: 0.3817
# Epoch 32/50
# 313/313 [==============================] - 4s 14ms/step - loss: 1.6612 - accuracy: 0.5234 - val_loss: 2.5876 - val_accuracy: 0.3849
# Epoch 33/50
# 313/313 [==============================] - 4s 14ms/step - loss: 1.6123 - accuracy: 0.5350 - val_loss: 2.5963 - val_accuracy: 0.3865
# Epoch 34/50
# 313/313 [==============================] - 4s 14ms/step - loss: 1.5699 - accuracy: 0.5486 - val_loss: 2.6140 - val_accuracy: 0.3800
# Epoch 35/50
# 313/313 [==============================] - 4s 14ms/step - loss: 1.5778 - accuracy: 0.5388 - val_loss: 2.6308 - val_accuracy: 0.3798
# Epoch 36/50
# 313/313 [==============================] - 4s 14ms/step - loss: 1.5435 - accuracy: 0.5499 - val_loss: 2.6566 - val_accuracy: 0.3786
# Epoch 37/50
# 313/313 [==============================] - 4s 14ms/step - loss: 1.5122 - accuracy: 0.5564 - val_loss: 2.6585 - val_accuracy: 0.3758
# Epoch 38/50
# 313/313 [==============================] - 4s 14ms/step - loss: 1.4926 - accuracy: 0.5587 - val_loss: 2.6792 - val_accuracy: 0.3820
# Epoch 39/50
# 313/313 [==============================] - 4s 14ms/step - loss: 1.4676 - accuracy: 0.5672 - val_loss: 2.7164 - val_accuracy: 0.3782
# Epoch 40/50
# 313/313 [==============================] - 4s 14ms/step - loss: 1.4452 - accuracy: 0.5728 - val_loss: 2.7669 - val_accuracy: 0.3753
# Epoch 41/50
# 313/313 [==============================] - 4s 14ms/step - loss: 1.4153 - accuracy: 0.5785 - val_loss: 2.7616 - val_accuracy: 0.3790
# Epoch 42/50
# 313/313 [==============================] - 4s 14ms/step - loss: 1.3886 - accuracy: 0.5851 - val_loss: 2.8250 - val_accuracy: 0.3752
# Epoch 43/50
# 313/313 [==============================] - 4s 14ms/step - loss: 1.3950 - accuracy: 0.5848 - val_loss: 2.8921 - val_accuracy: 0.3717
# Epoch 44/50
# 313/313 [==============================] - 4s 14ms/step - loss: 1.3724 - accuracy: 0.5900 - val_loss: 2.8876 - val_accuracy: 0.3762
# Epoch 45/50
# 313/313 [==============================] - 4s 14ms/step - loss: 1.3313 - accuracy: 0.5978 - val_loss: 2.8848 - val_accuracy: 0.3755
# Epoch 46/50
# 313/313 [==============================] - 4s 14ms/step - loss: 1.3291 - accuracy: 0.5971 - val_loss: 2.9293 - val_accuracy: 0.3713
# Epoch 47/50
# 313/313 [==============================] - 4s 14ms/step - loss: 1.2999 - accuracy: 0.6086 - val_loss: 2.9862 - val_accuracy: 0.3734
# Epoch 48/50
# 313/313 [==============================] - 4s 14ms/step - loss: 1.2972 - accuracy: 0.6073 - val_loss: 2.9733 - val_accuracy: 0.3741
# Epoch 49/50
# 313/313 [==============================] - 4s 14ms/step - loss: 1.2630 - accuracy: 0.6179 - val_loss: 2.9731 - val_accuracy: 0.3765
# Epoch 50/50
# 313/313 [==============================] - 4s 14ms/step - loss: 1.2462 - accuracy: 0.6175 - val_loss: 3.0335 - val_accuracy: 0.3740
# CPU times: user 2min 38s, sys: 58.5 s, total: 3min 37s
# Wall time: 4min 11s

# %% [markdown]
# > ## 4) 학습 결과 시각화

# %% [markdown]
# * Loss Visualization

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(Hist_mnist.history['loss']) + 1)

plt.figure(figsize = (9, 6))
plt.plot(epochs, Hist_mnist.history['loss'])
plt.plot(epochs, Hist_mnist.history['val_loss'])
# plt.ylim(0, 0.4)
plt.title('Training & Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'])
plt.grid()
plt.show()

# %% [markdown]
# > ## 5) Model Evaluate

# %% [markdown]
# * Loss & Accuracy

# %%
loss, accuracy = model.evaluate(X_test, y_test)

print('Loss = {:.5f}'.format(loss))
print('Accuracy = {:.5f}'.format(accuracy))
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 2.9577 - accuracy: 0.3773
# Loss = 2.95772
# Accuracy = 0.37730

# %% [markdown]
# #
# #
# #
# # The End
# #
# #
# #
